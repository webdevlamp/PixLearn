# %% [markdown]
# # TensorFlow & Keras Basics
# ## PixLearn - Learning Notebook

# %% [markdown]
# ### 1. Introduction to TensorFlow
# TensorFlow is an open-source machine learning framework developed by Google. Keras is a high-level neural networks API that runs on top of TensorFlow.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models
import numpy as np

print(f"TensorFlow version: {tf.__version__}")
print(f"Keras version: {keras.__version__}")

# %% [markdown]
# ### 2. Tensors - The Building Blocks

# %%
scalar = tf.constant(7)
vector = tf.constant([1, 2, 3, 4, 5])
matrix = tf.constant([[1, 2], [3, 4]])
tensor_3d = tf.constant([[[1, 2], [3, 4]], [[5, 6], [7, 8]]])

print(f"Scalar: {scalar}")
print(f"Vector: {vector}")
print(f"Matrix:\n{matrix}")
print(f"3D Tensor:\n{tensor_3d}")

# %% [markdown]
# ### 3. Building a Simple Neural Network

# %%
model = models.Sequential([
    layers.Dense(64, activation='relu', input_shape=(10,)),
    layers.Dense(32, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])

model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

model.summary()

# %% [markdown]
# ### 4. Loading MNIST Dataset

# %%
mnist = keras.datasets.mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train, x_test = x_train / 255.0, x_test / 255.0

print(f"Training data shape: {x_train.shape}")
print(f"Test data shape: {x_test.shape}")

# %% [markdown]
# ### 5. Visualizing Sample Images

# %%
import matplotlib.pyplot as plt

fig, axes = plt.subplots(1, 5, figsize=(10, 2))
for i in range(5):
    axes[i].imshow(x_train[i], cmap='gray')
    axes[i].set_title(f"Label: {y_train[i]}")
    axes[i].axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### 6. Building an MNIST Classifier

# %%
mnist_model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(10, activation='softmax')
])

mnist_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

mnist_model.summary()

# %% [markdown]
# ### 7. Training the Model

# %%
history = mnist_model.fit(
    x_train, y_train,
    epochs=5,
    validation_split=0.1
)

# %% [markdown]
# ### 8. Evaluating and Making Predictions

# %%
test_loss, test_acc = mnist_model.evaluate(x_test, y_test, verbose=2)
print(f"\nTest accuracy: {test_acc:.4f}")

predictions = mnist_model.predict(x_test)
predicted_label = np.argmax(predictions[0])
print(f"First prediction: {predicted_label} (actual: {y_test[0]})")

# %% [markdown]
# ### 9. Plotting Training History

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))
axes[0].plot(history.history['accuracy'], label='Train')
axes[0].plot(history.history['val_accuracy'], label='Validation')
axes[0].set_title('Accuracy')
axes[0].legend()
axes[1].plot(history.history['loss'], label='Train')
axes[1].plot(history.history['val_loss'], label='Validation')
axes[1].set_title('Loss')
axes[1].legend()
plt.show()
